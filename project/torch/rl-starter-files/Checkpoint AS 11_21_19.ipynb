# %%
import matplotlib.pyplot as plt
import pandas as pd

teach_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t1/log.csv'
noteach_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/nt1/log.csv'
teach_w_ha_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t_ha1/log.csv'
teach_w_ha_exp_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t_ha_exp1/log.csv'

path_names = [(teach_file_name,"teaching","red"),
              (noteach_file_name,"no teaching","blue"),
              (teach_w_ha_file_name,"ha","black"),
              (teach_w_ha_exp_file_name,"ha_exp","green")]

ax = plt.gca()
for path, name, colour in path_names:
    data = pd.read_csv(path)
    data.plot(kind='line',y='rreturn_mean',color=colour,ax=ax, label=name)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rreturn_mean'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1f64bf9ea2ee> in <module>
#      15 for path, name, colour in path_names:
#      16     data = pd.read_csv(path)
# ---> 17     data.plot(kind='line',y='rreturn_mean',color=colour,ax=ax, label=name)
#      18 plt.legend()
#      19 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     778
#     779                 # don't overwrite
# --> 780                 data = data[y].copy()
#     781
#     782                 if isinstance(data, ABCSeries):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rreturn_mean'

# %%
noteach_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/nt_10x10_s1/log.csv'
teach_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t_exp_10x10_s1/log.csv'

path_names = [(teach_file_name,"teaching","red"),(noteach_file_name,"no teaching","blue")]

ax = plt.gca()
for path, name, colour in path_names:
    data = pd.read_csv(path)
    data.plot(kind='line',x='update',y='rreturn_mean',color=colour,ax=ax, label=name)
plt.legend()
plt.show()

# %% [markdown]
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_30_s1_g2 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_exp_30_s1_g2 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2 --sampling_strategy exponential
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_30_s1_g2 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_30_s1_g2 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2

# %% [markdown]
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-10x10-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_10x10_s1 --teacher_algo a2c --student_algo ppo --seed 1
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_exp_10x10_s1 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2 --seed 1

# %%
teach_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t_11_27_1_3_o/log.csv'
noteach_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/nt_11_27_1_3_o/log.csv'
teach_w_ha_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t_ha_11_27_1_3_o/log.csv'
teach_w_ha_exp_file_name = '/Users/anandsranjan/Desktop/AsymmPlay/project/torch/rl-starter-files/storage/t_ha_11_27_1_3_o_exp/log.csv'

path_names = [(teach_file_name,"teaching","red"),(noteach_file_name,"no teaching","blue"),(teach_w_ha_file_name,"ha","black")]

ax = plt.gca()
for path, name, colour in path_names:
    data = pd.read_csv(path)
    data.plot(kind='line',x='update',y='rreturn_mean',color=colour,ax=ax, label=name)
plt.legend()
plt.show()

# %% [markdown]
# Commands:
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_11_21 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_11_21 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_11_21 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2

# %% [markdown]
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_11_21_1_3 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_11_21_1_3 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_11_21_1_3 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2 --inter

# %% [markdown]
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_11_21_3_1 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_11_21_3_1 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_11_21_3_1 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2

# %% [markdown]
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_11_21_3_1_s2 --teacher_algo a2c --student_algo ppo --seed 2
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_11_21_3_1_s2 --teacher_algo a2c --student_algo ppo --seed 2
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_11_21_3_1_s2 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2 --seed 2

# %% [markdown]
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-10x10-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_10env_11_21 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-10x10-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_10env_11_21 --teacher_algo a2c --student_algo ppo
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-10x10-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_10env_11_21 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2

# %% [markdown]
# Notes:
#
# Number of student iterations per teaching isn't doing the number I expected (I think?)
# Number of frames_teacher - what does this mean for us? Do we want to do it based of updates? Let's talk about this again.

# %% [markdown]
# Newer tests:
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --model nt_11_27_1_3_o_3 --teacher_algo a2c --student_algo ppo --seed 2
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_11_27_1_3_o_2 --teacher_algo a2c --student_algo ppo --seed 2
#
# python3 -m scripts.train --env MiniGrid-TeacherDoorKey-5x5-v0 --save-interval 10 --frames 80000 --procs 8 --nt_iters 50 --t_iters 10 --s_iters_per_teaching 5 --model t_ha_11_27_1_3_o_3 --teacher_algo a2c --student_algo ppo --historical_averaging 0.2 --seed 2
